# %%
import sys

sys.path.append("../")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from positioning.readwav import readwav
from positioning.create_db import create_db
from positioning.estimate import estimate
from positioning.get_spectrum_amplitude import get_spectrum_amplitude

# %%
wav = readwav("../data/vivesound_0513/s10m0.wav")
plt.plot(wav)

# %%
spec, ampli = get_spectrum_amplitude(wav, plot=True)
# Out:
# 44986
# /Users/ange0/miniforge3/envs/lab/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
